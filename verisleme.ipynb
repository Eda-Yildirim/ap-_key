# %%
# Gerekli kütüphaneleri yükledim
# !pip install --upgrade google-api-python-client

# Gerekli modülü içe aktarıldı
from googleapiclient.discovery import build

# API anahtarımı ekledim
api_key = "AIzaSyAWvMxT1-zR5EYotFlpfg_fehXL2qbphbs"

# YouTube API bağlantısını kurdum
youtube = build("youtube", "v3", developerKey=api_key)

print("YouTube API bağlantısı kuruldu.")
# Out:
# Requirement already up-to-date: google-api-python-client in c:\users\casper\anaconda3\lib\site-packages (2.169.0)
# Requirement already satisfied, skipping upgrade: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\casper\anaconda3\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied, skipping upgrade: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\casper\anaconda3\lib\site-packages (from google-api-python-client) (2.40.1)
# Requirement already satisfied, skipping upgrade: uritemplate<5,>=3.0.1 in c:\users\casper\anaconda3\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied, skipping upgrade: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\casper\anaconda3\lib\site-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied, skipping upgrade: httplib2<1.0.0,>=0.19.0 in c:\users\casper\anaconda3\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4 in c:\users\casper\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\casper\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.3.0)
# Requirement already satisfied, skipping upgrade: cachetools<6.0,>=2.0.0 in c:\users\casper\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied, skipping upgrade: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\casper\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (4.24.4)
# Requirement already satisfied, skipping upgrade: proto-plus<2.0.0,>=1.22.3 in c:\users\casper\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\casper\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.18.0 in c:\users\casper\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2; python_version > "3.0" in c:\users\casper\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (2.4.2)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in c:\users\casper\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.5.1)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in c:\users\casper\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in c:\users\casper\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.0.7)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\casper\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2024.8.30)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in c:\users\casper\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.3.2)
# YouTube API bağlantısı kuruldu.

# %%
# Kullanıcı adı (handle)
username = "sisterslaborg"

# API üzerinden kullanıcı adına karşılık kanal bilgisini alma
request = youtube.search().list(
    part="snippet",
    q=username,
    type="channel",
    maxResults=1
)
response = request.execute()

# Kanal ID’sini al
if response["items"]:
    channel_id = response["items"][0]["snippet"]["channelId"]
    print(f"Kanal ID'si: {channel_id}")
else:
    print("Kanal bulunamadı.")
# Out:
# Kanal ID'si: UCDLlvoriOfvbfUL3P1SyGkg

# %%
# Bilgilerini almak istediğin kanal ID'si (sisterslab)
channel_id = "UCDLlvoriOfvbfUL3P1SyGkg"

# Kanal bilgisi çekme isteği
request = youtube.channels().list(
    part="snippet,statistics",
    id=channel_id
)

response = request.execute()

# Gelen veriyi işleme ve ekrana yazdırma
if response["items"]:
    channel = response["items"][0]
    title = channel["snippet"]["title"]
    description = channel["snippet"]["description"]
    subscribers = channel["statistics"].get("subscriberCount", "Gizli")
    video_count = channel["statistics"]["videoCount"]
    thumbnail_url = channel["snippet"]["thumbnails"]["high"]["url"]

    # Ekrana düzgün çıktı
    print("Kanal Bilgileri:")
    print(f"Kanal Adı: {title}")
    print(f"Açıklama: {description[:150]}...")
    print(f" Abone Sayısı: {subscribers}")
    print(f"Video Sayısı: {video_count}")
    print(f"Profil Resmi URL: {thumbnail_url}")
else:
    print("⚠️ Kanal bulunamadı.")
# Out:
# Kanal Bilgileri:
# Kanal Adı: SistersLab | Bilim ve Teknolojide Kadın Derneği
# Açıklama: ⚧ STEM alanlarında kız çocukları & kadınları güçlendirmek ve toplumsal cinsiyet eşitliği farkındalığını artırmak için çalışıyoruz.💪🏽👩‍💻
#
# hello@sister...
#  Abone Sayısı: 1450
# Video Sayısı: 160
# Profil Resmi URL: https://yt3.ggpht.com/xDUsYGY4wFsJUUH-iGvDvyOaLlaLEJ95iQJr6IOlw6rfJ6-KCPu5h26qwRmutt5_HczdjhAsUTY=s800-c-k-c0x00ffffff-no-rj
